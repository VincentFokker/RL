# %%
from rl.helpers import Load_data
import pathlib
from os.path import join
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
path = pathlib.Path().absolute()
scalars = ['episode_reward', 'loss/loss']
timevar = 'step'  # wall_time or step

#for the different designs
# to_combine=[
#     ['AbstractConveyor1','20201216_1300'],
#     ['AbstractConveyor1', '20201214_1000'],
#     ['AbstractConveyor1','20201216_1330'],
#     ['AbstractConveyor1','20201216_2200'],
#     ['AbstractConveyor1','20201216_2230'],
#     ['AbstractConveyor1','20201216_2300']
    
# ]

##for the adjusted queue length
# to_combine=[
#     ['ConveyorEnv11','20210108_1400'], #1
#     ['ConveyorEnv11','20210108_1500'], #2
#     ['ConveyorEnv11','20210108_1600'], #3
#     ['ConveyorEnv11','20210108_1700'], #4
#     ['ConveyorEnv11','20210108_1800'], #5
#     ['ConveyorEnv11','20210108_1900'], #6
#     ['ConveyorEnv11','20210108_2000'], #7
#     ['ConveyorEnv11','20210108_2100'], #8
#     ['ConveyorEnv11','20210108_2200'], #9
#     ['ConveyorEnv11','20210108_2300'] #10
    
# ]

#compare different obs
# to_combine=[
#     ['AbstractConveyor2','20201217_1500'], #1
#     ['AbstractConveyor2','20201218_1426'] #2
# ]

# #for the different pipe length
to_combine=[
    ['ConveyorEnv11','20210109_1000'], #5
    ['ConveyorEnv11','20210109_1100'], #10
    ['ConveyorEnv11','20210109_1200'], #15
    ['ConveyorEnv11','20210109_1300'], #20
    ['ConveyorEnv11','20210109_1400'], #25
    ['ConveyorEnv11','20210109_1500'], #30
    ['ConveyorEnv11','20210109_1600'], #35
    ['ConveyorEnv11','20210109_1700'], #40
    
]

# %%
all_rewardplots = []
for env, subdir in to_combine:
    data = Load_data(env, subdir, scalar='episode_reward')
    all_rewardplots.append(data)
# Out:
# start import 0 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 1 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 2 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 3 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 4 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 5 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 6 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 7 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 8 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 9 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 0 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 1 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 2 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 3 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 4 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 5 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 6 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 7 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 8 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 9 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 0 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 1 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 2 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 3 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 4 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 5 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 6 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 7 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 8 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 9 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 0 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 1 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 2 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 3 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 4 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 5 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 6 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 7 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 8 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 9 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 0 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 1 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 2 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 3 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 4 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 5 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 6 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 7 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 8 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 9 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 0 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 1 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 2 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 3 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 4 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 5 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 6 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 7 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 8 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 9 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 0 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 1 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 2 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 3 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 4 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 5 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 6 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 7 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 8 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 9 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 0 / 8 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 1 / 8 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 2 / 8 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 3 / 8 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 4 / 8 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 5 / 8 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 6 / 8 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# import from tensorboard event done

# %%
plt.style.use('ggplot')

timevar = 'step'     #step or wall_time
#labels = ['1x2 design', '2x2 design', '2x3 design', '3x3 design', '4x3 design', '5x3 design']
#labels = ['buffer size {}'.format(i) for i in range(1,11)]
labels = ['Pipeline length {}'.format(i) for i in range(10,55,5)]
#labels = labels + ['new 35', 'new 40', 'new 45', 'new 50']

#determine colors

intdata = (np.array(sns.color_palette("viridis", len(all_rewardplots))) * 255).astype(int)
hexen = ['#%02x%02x%02x' % tuple(code) for code in intdata]

fig = plt.figure(figsize=(15, 6))
for idx, df in enumerate(all_rewardplots):
    plt.plot(df[timevar], df.value, color =hexen[idx], alpha=0.10)
for idx, df in enumerate(all_rewardplots):
    plt.plot(df[timevar], df.value_s, color = hexen[idx], label=labels[idx])
plt.xlabel('Timestep')
plt.ylabel('Episode Reward')
plt.legend()
#plt.savefig('figures/episode_reward_designs_6.png')
#plt.savefig('figures/reward_diff_buffer.png')
plt.savefig('figures/reward_diff_pipe.png')
plt.show()

# %%
for idx, df in enumerate(all_rewardplots):
    fig = plt.figure(figsize=(15, 6))
    plt.plot(df[timevar], df.value, color =hexen[idx], alpha=0.15)
    plt.plot(df[timevar], df.value_s, color = hexen[idx], label=labels[idx])
    plt.xlabel('Timestep')
    plt.ylabel('Episode Reward')
    plt.legend()
    plt.savefig('figures/reward_{}.png'.format(labels[idx]))
    plt.show()

# %%
all_loss = []
for env, subdir in to_combine:
    data = Load_data(env, subdir, scalar='loss/loss',smoothing=0.99)
    all_loss.append(data)
# Out:
# start import 0 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 1 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 2 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 3 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 4 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 5 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 6 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 7 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 8 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 9 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 0 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 1 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 2 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 3 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 4 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 5 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 6 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 7 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 8 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 9 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 0 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 1 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 2 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 3 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 4 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 5 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 6 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 7 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 8 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 9 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 0 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 1 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 2 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 3 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 4 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 5 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 6 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 7 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 8 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 9 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 0 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 1 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 2 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 3 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 4 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 5 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 6 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 7 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 8 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 9 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 0 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 1 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 2 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 3 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 4 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 5 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 6 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 7 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 8 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 9 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 0 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 1 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 2 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 3 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 4 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 5 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 6 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 7 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 8 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 9 / 10 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 0 / 8 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 1 / 8 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 2 / 8 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 3 / 8 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 4 / 8 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 5 / 8 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 6 / 8 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done
# start import 7 / 8 from tensorboard event
# WARNING:tensorboard:Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# import from tensorboard event done

# %%
# determine colors

intdata = (np.array(sns.color_palette("viridis", len(all_loss)+2)) * 255).astype(int)
hexen = ['#%02x%02x%02x' % tuple(code) for code in intdata[2:]]

fig = plt.figure(figsize=(15, 5), dpi=300)
for idx, df in enumerate(all_loss):
    plt.plot(df[timevar], df.value, color =hexen[idx], alpha=0.15)
for idx, df in enumerate(all_loss):
    plt.plot(df[timevar], df.value_s, color = hexen[idx], label=labels[idx])
plt.xlabel('Timestep')
plt.ylabel('Loss / loss')
plt.legend()
#plt.savefig('figures/loss_designs.png')
#plt.savefig('figures/loss_diff_buffer.png')
plt.savefig('figures/loss_diff_pipe.png')
plt.show()

# %%
for idx, df in enumerate(all_loss):
    fig = plt.figure(figsize=(15, 6))
    plt.plot(df[timevar], df.value, color =hexen[idx], alpha=0.15)
    plt.plot(df[timevar], df.value_s, color = hexen[idx], label=labels[idx])
    plt.xlabel('Timestep')
    plt.ylabel('Loss/loss')
    plt.legend()
    plt.savefig('figures/loss_{}.png'.format(labels[idx]))
    plt.show()
